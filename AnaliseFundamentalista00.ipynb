# %% [markdown]
# <a href="https://colab.research.google.com/github/rafaeltsimon/PythonQuant/blob/main/AnaliseFundamentalista00.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install fundamentus
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 3.1 MB/s eta 0:00:00
# ...

# %%
import fundamentus

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Screening**

# %%
df=fundamentus.get_resultado()
# Out:
# /usr/local/lib/python3.10/dist-packages/fundamentus/resultado.py:50: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(content.text, decimal=",", thousands='.')[0]

# %%
df.head()
# Out:
# Multiples  cotacao      pl   pvp    psr      dy     pa    pcg  pebit   pacl  \
# papel
# AALR3        14.50   -7.85  1.58  1.443  0.0000  0.637 -11.03  33.74  -1.70
# ABCB3         0.00    0.00  0.00  0.000  0.0000  0.000   0.00   0.00   0.00
# ABCB4        24.03    6.30  0.94  0.000  0.0625  0.000   0.00   0.00   0.00
# ABEV3        12.94   14.16  2.14  2.529  0.0564  1.422  55.14  11.80 -22.44
# ABYA3         4.91 -214.80  1.76  2.055  0.0000  0.527   1.98  19.96  -2.75
#
# Multiples  evebit  evebitda  mrgebit  mrgliq    roic     roe  liqc  \
# papel
# AALR3       45.29     14.35   0.0428 -0.1752  0.0221 -0.2006  0.78
# ABCB3        0.00      0.00   0.0000  0.0000  0.0000  0.1496  0.00
# ABCB4        0.00      0.00   0.0000  0.0000  0.0000  0.1496  0.00
# ABEV3       11.11      8.19   0.2143  0.1836  0.1582  0.1511  1.11
# ABYA3       33.67     33.67   0.1029 -0.0096  0.0278 -0.0082  2.09
#
# Multiples        liq2m       patrliq  divbpatr     c5y
# papel
# ...

# %%
df.loc["ABCB4"]
# Out:
# Multiples
# cotacao     2.403000e+01
# pl          6.300000e+00
# pvp         9.400000e-01
# psr         0.000000e+00
# dy          6.250000e-02
# pa          0.000000e+00
# pcg         0.000000e+00
# pebit       0.000000e+00
# pacl        0.000000e+00
# evebit      0.000000e+00
# evebitda    0.000000e+00
# mrgebit     0.000000e+00
# mrgliq      0.000000e+00
# roic        0.000000e+00
# roe         1.496000e-01
# liqc        0.000000e+00
# liq2m       1.589530e+07
# patrliq     6.235070e+09
# divbpatr    0.000000e+00
# c5y         1.350000e-01
# Name: ABCB4, dtype: float64

# %%
df.loc[["ABCB4", "GNDI3"],["pl"]]
# Out:
# Multiples       pl
# papel
# ABCB4         6.30
# GNDI3     -3584.82

# %%
setor = ["ABEV3", "PETR4"]

# %%
df.query("index in @setor")
# Out:
# Multiples  cotacao     pl   pvp    psr      dy     pa    pcg  pebit   pacl  \
# papel
# ABEV3        12.94  14.16  2.14  2.529  0.0564  1.422  55.14  11.80 -22.44
# PETR4        38.29   6.34  1.34  1.001  0.1380  0.472 -26.76   2.22  -0.95
#
# Multiples  evebit  evebitda  mrgebit  mrgliq    roic     roe  liqc  \
# papel
# ABEV3       11.11      8.19   0.2143  0.1836  0.1582  0.1511  1.11
# PETR4        3.39      2.56   0.4515  0.1587  0.2337  0.2109  0.90
#
# Multiples         liq2m       patrliq  divbpatr     c5y
# papel
# ABEV3      3.452760e+08  9.526280e+10      0.04  0.1156
# PETR4      1.144560e+09  3.734790e+11      0.89  0.1869

# %% [markdown]
# Filtro dos papéis com P\L acima de 15 e DY acima de 5%

# %%
filtro=df[(df.pl > 15) & (df.dy > 0.05)]

# %%
filtro
# Out:
# Multiples  cotacao     pl   pvp    psr      dy     pa     pcg  pebit   pacl  \
# papel
# AFLT3         7.16  16.06  1.87  8.461  0.0813  1.459   16.37  13.90  34.94
# ALOS3        23.37  18.77  0.91  4.653  0.0506  0.461    5.35   9.97  -1.58
# GEPA3        25.01  15.83  0.00  3.426  0.1677  0.000    0.00  14.03   0.00
# GEPA4        26.00  16.45  0.00  3.561  0.1613  0.000    0.00  14.59   0.00
# JBSS3        36.13  19.95  1.73  0.212  0.0554  0.365    2.52   5.74  -0.93
# KLBN11       21.95  16.92  2.88  1.484  0.0533  0.472    2.16   7.68  -1.02
# KLBN3         4.43  17.07  2.91  1.498  0.0528  0.476    2.18   7.75  -1.03
# KLBN4         4.38  16.88  2.88  1.481  0.0534  0.471    2.15   7.66  -1.02
# PARD3        20.25  36.76  5.30  2.565  0.0522  2.095  -54.06  17.52  -8.62
# PATI4        35.00  22.56  0.96  0.446  0.0602  0.514    1.18  10.75   1.85
# PGMN3         3.33  20.16  0.73  0.165  0.0827  0.226    1.40   4.06  -1.11
# ...

# %%
plt.figure(figsize=(8, 10))
filtro.sort_values("mrgebit", inplace = True)
plt.bar(filtro.index, filtro.mrgebit)
# Out:
# <ipython-input-19-b6fd6bafda1e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtro.sort_values("mrgebit", inplace = True)
# <BarContainer object of 21 artists>

# %%
filtro2 = df[(df.pl > 0) & (df.dy > 0.05) & (df.mrgebit > 0.3)]

# %%
plt.figure(figsize=(18, 10))
filtro2.sort_values("dy", inplace = True, ascending = False)
plt.bar(filtro2.index, filtro2.dy,)
plt.xticks(rotation = 45)
plt.title("Ações top")
# Out:
# <ipython-input-26-011bb4364391>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtro2.sort_values("dy", inplace = True, ascending = False)
# Text(0.5, 1.0, 'Ações top')
